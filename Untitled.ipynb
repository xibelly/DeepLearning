# %%
import pandas as pd
import numpy as np

# %%
#+++++ Reading: data set +++++
print("Reading the data set\n")

name_file = "/home/xibelly/Escritorio/file.csv"

BD = pd.read_csv(name_file)
N = len(BD)

print(N)
#nrow(BD[UBICACION_DE_LA_OFICINA == 'CALIFORNIA', ])
# Out:
# Reading the data set
#
# 8000

# %%
display(BD)
# Out:
#            RECORD_CREATION_DATE  MONTO_DEL_PRESTAMO RANGO_DEL_CREDITO  \
# 0     01May2014:09:24:27.000000                2500           760-779
# 1     01May2014:09:48:36.000000                2500           700-719
# 2     01May2014:10:10:36.000000                6300           740-759
# 3     01May2014:10:31:25.000000                4300           780-799
# 4     01May2014:10:46:54.000000               20100           780-799
# 5     01May2014:11:14:12.000000                6600           760-779
# 6     01May2014:11:23:11.000000                2500           700-719
# 7     01May2014:11:53:24.000000               10000           760-779
# 8     01May2014:12:18:53.000000                8900           740-759
# 9     01May2014:12:32:41.000000                2500           760-779
# 10    01May2014:12:52:26.000000               13000           720-739
# 11    01May2014:12:59:04.000000                2500           780-799
# ...

# %%
new = BD["UBICACION_DE_LA_OFICINA"].isin(["NORTHERN CALIFORNIA"])

#BD[new].count()
new = BD[['UBICACION_DE_LA_OFICINA'] == 'NORTHERN CALIFORNIA']
new.count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /etc/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-7968536335cd> in <module>()
#       2
#       3 #BD[new].count()
# ...

# %%
new.count()
# Out:
# 8000
